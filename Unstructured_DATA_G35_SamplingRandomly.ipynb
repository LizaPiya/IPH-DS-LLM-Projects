# %% [markdown]
# <a href="https://colab.research.google.com/github/LizaPiya/IPH-DS-LLM-Projects/blob/main/Unstructured_DATA_G35_SamplingRandomly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# Import the necessary module for downloading files
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
G35_Unstructured ='/content/drive/MyDrive/Fahmida Liza Piya/UnstructuredG35.csv'
G35_Unstructured_df=pd.read_csv(G35_Unstructured)
G35_Unstructured_df.head(5)
# Out:
# <ipython-input-3-c3633ac0c9f8>:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   G35_Unstructured_df=pd.read_csv(G35_Unstructured)
#    nextgengroupid  referencedatetime  clinicid  reportingdate  \
# 0           87210       202303090911       668       20230301
# 1           87210       202303090911       668       20230301
# 2           31622       201510191030       666       20151001
# 3           31622       201510191030       666       20151001
# 4           31622       201510191030       666       20151001
#
#                       fileheader  reportingenterpriseid  standardpreamble  \
# 0  -|0|LSDX|00668|20230501050722                    668            50.001
# 1  -|0|LSDX|00668|20230501050722                    668            50.001
# 2  -|0|LSDX|00666|20160629012708                    666            50.001
# 3  -|0|LSDX|00666|20160629012708                    666            50.001
# ...

# %%
#take 5 percent of data from the G35_Unstructured_df
G35_Unstructured_df_sample = G35_Unstructured_df.sample(frac=0.05)
G35_Unstructured_df_sample.head(5)
# Out:
#          nextgengroupid  referencedatetime  clinicid  reportingdate  \
# 8420576          102297       202212071330       998       20221201
# 1297207          149434       202307271300       825       20230701
# 6386943          165792       201608080855       998       20160801
# 2346125          182251       201805091107       998       20191201
# 1650516           48777       202209191516       998       20220901
#
#                             fileheader  reportingenterpriseid  \
# 8420576  -|0|LSDX|00998|20230201235937                    998
# 1297207  -|0|LSDX|00825|20230904123242                    825
# 6386943  -|0|LSDX|00998|20161117152202                    998
# 2346125  -|0|LSDX|00998|20200202140414                    998
# 1650516  -|0|LSDX|00998|20221102021726                    998
#
#          standardpreamble  encounterid  encounterdate  diagnosisdate  ...  \
# 8420576            50.001      4196150       20221207   202212071330  ...
# ...

# %%
G35_Unstructured_df_sample.nunique()
# Out:
# nextgengroupid               4433
# referencedatetime           82904
# clinicid                      216
# reportingdate                 108
# fileheader                   2804
# reportingenterpriseid         216
# standardpreamble                1
# encounterid                108750
# encounterdate                2622
# diagnosisdate               82904
# onsetdate                    2624
# emrcode                         1
# dateresolved                    8
# statusid                       34
# statusidtext                   22
# dxpriority                     13
# snomedconceptid                 0
# patientpseudonymtoken        3693
# raw                        124152
# tranche                         8
# nextgengroupid.1             3654
# referencedatetime.1         24265
# clinicid.1                     16
# reportingdate.1                23
# fileheader.1                  279
# reportingenterpriseid.1        16
# standardpreamble.1              1
# ...

# %%
G35_Unstructured_df_sample.to_csv('G35_Unstructured_df_sample.csv')

# %%
# Download the sampled CSV file
files.download('G35_Unstructured_df_sample.csv')
